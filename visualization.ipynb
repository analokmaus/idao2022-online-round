# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
exp_path = Path('results/exp_19_b')

# %%
# fig = plt.figure(figsize=(12, 6))
# ax1 = fig.add_subplot(1, 2, 1)
# ax2 = fig.add_subplot(1, 2, 2)
# for i in range(5):
#     log_fold = pd.read_csv(exp_path/f'fold_{i}.csv')
#     log_fold.plot(x='epoch', y='trn_loss', kind='line', ax=ax1, grid=True, label=f'fold{i+1}')
#     log_fold.plot(x='epoch', y='trn_energy_within_threshold', kind='line', ax=ax2, grid=True, label=f'fold{i+1}')

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
logfile = pd.read_csv(exp_path/f'results.csv')
logfile.plot(x='epoch', y='loss', kind='line', ax=ax1, grid=True, label=f'loss')
logfile.plot(x='epoch', y='metric', kind='line', ax=ax2, grid=True, label=f'metric')
# Out:
# <AxesSubplot:xlabel='epoch'>
